# %% [markdown]
# ## **ETL**

# %%
import requests
import pandas as pd
# !pip install sqlalchemy pymysql
# !pip install sqlalchemy pyodbc
import time
import pyodbc
from datetime import datetime
from sqlalchemy import create_engine, NVARCHAR, FLOAT, inspect
import logging
from tqdm import tqdm
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\david\anaconda3\lib\site-packages (1.4.39)
# Requirement already satisfied: pymysql in c:\users\david\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\david\anaconda3\lib\site-packages (from sqlalchemy) (2.0.1)
# Requirement already satisfied: sqlalchemy in c:\users\david\anaconda3\lib\site-packages (1.4.39)
# Requirement already satisfied: pyodbc in c:\users\david\anaconda3\lib\site-packages (4.0.34)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\david\anaconda3\lib\site-packages (from sqlalchemy) (2.0.1)

# %% [markdown]
# ## **Connection to the SQL db (SINK)**

# %%
# SQL Server details

SERVER = '(localdb)\\localdb'
DATABASE = 'Irceline'
DRIVER = 'ODBC Driver 18 for SQL Server'
CONNECTION_STRING = f'mssql+pyodbc://{SERVER}/{DATABASE}?driver={DRIVER.replace(" ", "+")}&trusted_connection=yes'
engine = create_engine(CONNECTION_STRING, fast_executemany=True)

# %% [markdown]
# ## **API**

# %%
url = "https://geo.irceline.be/sos/api/v1/stations"
response = requests.get(url)
stations = response.json()

# %%
url1 = "https://geo.irceline.be/sos/api/v1/timeseries"
response1 = requests.get(url1)
timeseries = response1.json()

# %%
url2 = "https://geo.irceline.be/sos/api/v1/categories"
response2 = requests.get(url2)
category = response2.json()

# %%
# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# API Configuration
TIMESERIES_URL = "https://geo.irceline.be/sos/api/v1/timeseries"


def fetch_api_data(url):
    logger.info(f"Fetching URL: {url}")
    try:
        response = requests.get(url, headers={"Accept": "application/json"}, timeout=30)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        logger.warning(f"API request failed for {url}: {str(e)}")
        return None
    
def load_measurements():
    ts_df = pd.read_sql("SELECT id AS timeseries_id FROM timesseriesdata", engine)

    for _, row in tqdm(ts_df.iterrows(), total=ts_df.shape[0], desc="Fetching measurements"):
        ts_id = row['timeseries_id']
        url = f"{TIMESERIES_URL}/{ts_id}/getData?timespan=2025-01-01TZ/2025-07-06TZ"
        logger.info(f"Fetching timeseries data from: {url}")

        values = fetch_api_data(url)
        if not values or 'values' not in values:
            logger.warning(f"No 'values' found for timeseries {ts_id}")
            continue

        records = []
        for point in values['values']:
            timestamp_raw = point.get('timestamp')
            value_raw = point.get('value')

            if value_raw is None or timestamp_raw is None:
                continue

            try:
                timestamp = datetime.utcfromtimestamp(timestamp_raw / 1000)
                value = float(value_raw)
                records.append({
                    "timeseries_id": ts_id,
                    "timestamp": timestamp,
                    "value": value
                })
            except Exception as e:
                logger.warning(f"Skipping invalid data point in timeseries {ts_id}: {e}")
                continue

        if records:
            pd.DataFrame(records).to_sql("measurements", engine, if_exists="append", index=False)

# === ETL Run ===
load_measurements()
print("✅ Measurements data loaded.")
# Out:
# Fetching measurements:   0%|          | 0/658 [00:00<?, ?it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/6522/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/6522/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:   0%|          | 1/658 [00:00<04:30,  2.43it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/10892/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/10892/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:   0%|          | 2/658 [00:01<07:27,  1.47it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/10893/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/10893/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:   0%|          | 3/658 [00:02<08:06,  1.35it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/10932/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/10932/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:   1%|          | 4/658 [00:02<06:26,  1.69it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/10933/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/10933/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:   1%|          | 5/658 [00:03<06:55,  1.57it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/10934/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/10934/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:   1%|          | 6/658 [00:03<07:16,  1.49it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/10944/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/10944/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:   1%|          | 7/658 [00:04<08:02,  1.35it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/10982/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/10982/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:   1%|          | 8/658 [00:05<08:59,  1.20it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/10983/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/10983/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:   1%|▏         | 9/658 [00:06<09:42,  1.11it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/10984/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/
/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99902/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99902/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  96%|█████████▌| 632/658 [08:10<00:18,  1.39it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99905/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99905/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  96%|█████████▌| 633/658 [08:11<00:18,  1.33it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99908/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99908/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  96%|█████████▋| 634/658 [08:11<00:15,  1.59it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99911/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99911/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  97%|█████████▋| 635/658 [08:12<00:16,  1.35it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99914/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99914/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  97%|█████████▋| 636/658 [08:12<00:13,  1.62it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99917/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99917/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  97%|█████████▋| 637/658 [08:13<00:15,  1.36it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99920/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99920/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  97%|█████████▋| 638/658 [08:14<00:15,  1.26it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99923/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99923/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  97%|█████████▋| 639/658 [08:15<00:15,  1.20it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99926/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99926/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  97%|█████████▋| 640/658 [08:16<00:15,  1.19it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99929/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99929/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  97%|█████████▋| 641/658 [08:17<00:16,  1.05it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99932/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99932/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  98%|█████████▊| 642/658 [08:18<00:15,  1.02it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99935/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99935/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  98%|█████████▊| 643/658 [08:19<00:14,  1.00it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99938/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99938/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  98%|█████████▊| 644/658 [08:20<00:13,  1.04it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99941/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99941/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  98%|█████████▊| 645/658 [08:21<00:10,  1.29it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/6520/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/6520/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  98%|█████████▊| 646/658 [08:21<00:07,  1.57it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99900/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99900/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  98%|█████████▊| 647/658 [08:21<00:05,  1.83it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99903/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99903/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  98%|█████████▊| 648/658 [08:22<00:04,  2.07it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99906/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99906/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  99%|█████████▊| 649/658 [08:22<00:03,  2.27it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99909/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99909/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  99%|█████████▉| 650/658 [08:22<00:03,  2.42it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99915/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99915/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  99%|█████████▉| 651/658 [08:23<00:04,  1.72it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99939/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99939/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  99%|█████████▉| 652/658 [08:23<00:02,  2.02it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99901/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99901/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  99%|█████████▉| 653/658 [08:24<00:02,  2.27it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99904/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99904/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements:  99%|█████████▉| 654/658 [08:24<00:01,  2.51it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99907/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99907/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements: 100%|█████████▉| 655/658 [08:24<00:01,  2.65it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99910/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99910/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements: 100%|█████████▉| 656/658 [08:25<00:00,  2.85it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99916/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99916/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements: 100%|█████████▉| 657/658 [08:26<00:00,  1.99it/s]INFO:__main__:Fetching timeseries data from: https://geo.irceline.be/sos/api/v1/timeseries/99940/getData?timespan=2025-01-01TZ/2025-07-06TZ
# INFO:__main__:Fetching URL: https://geo.irceline.be/sos/api/v1/timeseries/99940/getData?timespan=2025-01-01TZ/2025-07-06TZ
# Fetching measurements: 100%|██████████| 658/658 [08:26<00:00,  1.30it/s]
# ✅ Measurements data loaded.

# %% [markdown]
# ## **Data Transformation**

# %%
flattened = []
for feature in stations:
    flattened.append({
        "id": feature["properties"]["id"],
        "label": feature["properties"]["label"],
        "longitude": feature["geometry"]["coordinates"][0],
        "latitude": feature["geometry"]["coordinates"][1],
        "altitude": feature["geometry"]["coordinates"][2] if len(feature["geometry"]["coordinates"]) > 2 else None,
        "geometry_type": feature["geometry"]["type"],
        "feature_type": feature["type"]
    })

# Convert to DataFrame
df_stations = pd.DataFrame(flattened)

# Extract just the city name (second part after first hyphen)
df_stations['city'] = df_stations['label'].str.split(' - ').str[1]

# Optionally, you can clean up the city name by removing any trailing whitespace
df_stations['city'] = df_stations['city'].str.strip()

# If you want to keep only the city column and drop the original label:
# df_stations.drop('label', axis=1, inplace=True)

# Or if you want to keep both:
df_stations = df_stations[['id', 'city', 'latitude', 'longitude']]
df_stations[['city_main', 'city_district']] = (
    df_stations['city']
    .str.extract(r'^([^(]+)(?:\s*\((.*)\))?$')
    .fillna('')  # Replace NaN (no match) with empty string
)
df_stations.drop(['city'], axis=1, inplace = True)
mask = df_stations['city_main'] == 'Arts-Loi'
df_stations.loc[mask, 'city_district'] = 'Arts-Loi ' + df_stations.loc[mask, 'city_district']
df_stations.loc[mask, 'city_main'] = 'Bruxelles'
df_stations['city_main'] = df_stations['city_main'].str.strip()
df_stations['city_district'] = df_stations['city_district'].str.strip()
df_stations['city_main'] = df_stations['city_main'].replace('Brussel', 'Bruxelles')

df_stations.to_sql(
    name='stations',        # target table name
    con=engine,             # SQLAlchemy engine
    if_exists='replace',    # 'replace', 'append', or 'fail'
    index=False,            # do not write DataFrame index as a column
)
# Out:
# -1

# %%
# Flatten timeseries

flat_data_list = []

for data in timeseries:
    flat_data = {
        "id": data["id"],
        "label": data["label"],
        "uom": data["uom"],
        "station_id": data["station"]["properties"]["id"],
        "station_label": data["station"]["properties"]["label"],
        "longitude": data["station"]["geometry"]["coordinates"][0],
        "latitude": data["station"]["geometry"]["coordinates"][1],
        "altitude": data["station"]["geometry"]["coordinates"][2],
        "geometry_type": data["station"]["geometry"]["type"],
        "station_type": data["station"]["type"]
    }
    flat_data_list.append(flat_data)

df_ts = pd.DataFrame(flat_data_list)

# Split the label column into multiple components
df_ts[['parameter', 'id_part', 'device_type', 'station_info']] = df_ts['label'].str.split(' - ', n=3, expand=True)
print(df_ts.head(5))

# Further split the measurement into name and ID (since ID is already a column)
df_ts['parameter_name'] = df_ts['parameter'].str.replace(r' \d+$', '', regex=True)
df_ts['parameter_id'] = df_ts['parameter'].str.extract(r'(\d+)$')
df_stations.drop(['station_label', 'longitude', 'latitude', 'altitude', 'geometry_type', 'station_info'], axis=1, inplace = True)

print(df_ts.head(5))
df_ts.to_sql(
    name='timesseriesdata',        # target table name
    con=engine,             # SQLAlchemy engine
    if_exists='replace',    # 'replace', 'append', or 'fail'
    index=False,            # do not write DataFrame index as a column
)
# Out:
#       id                                              label    uom  \
# 0   6522  1,2-XYLENE O-XYLENE 6522 - btx, o-xyleen - pro...  µg/m³
# 1  10892  Ammonia 10892 - MINI DOAS - procedure, 42BO01 ...  µg/m³
# 2  10893  Ammonia 10893 - MINI DOAS - procedure, 42OT02 ...  µg/m³
# 3  10932  Ammonia 10932 - Unknown device - procedure, 43...  µg/m³
# 4  10933  Ammonia 10933 - Unknown device - procedure, 43...  µg/m³
#
#    station_id                                      station_label  longitude  \
# 0        6522  41B006 - Bruxelles (Parlement UE) - 1,2-XYLENE...   4.374388
# 1       10892             42BO01 - Bonheiden - Ammonia - feature   4.516484
# 2       10893          42OT02 - Oud-Turnhout - Ammonia - feature   5.011793
# 3       10932       43N063 - Corroy-Le-Grand - Ammonia - feature   4.668288
# 4       10933               43N100 - Dourbes - Ammonia - feature   4.594763
#
#     latitude altitude geometry_type station_type                 parameter  \
# 0  50.838631      NaN         Point      Feature  1,2-XYLENE O-XYLENE 6522
# 1  51.027061      NaN         Point      Feature             Ammonia 10892
# 2  51.346548      NaN         Point      Feature             Ammonia 10893
# 3  50.655439      NaN         Point      Feature             Ammonia 10932
# 4  50.095683      NaN         Point      Feature             Ammonia 10933
#
#           id_part        device_type  \
# 0   btx, o-xyleen  procedure, 41B006
# 1       MINI DOAS  procedure, 42BO01
# 2       MINI DOAS  procedure, 42OT02
# 3  Unknown device  procedure, 43N063
# 4  Unknown device  procedure, 43N100
#
#                                         station_info
# 0  Bruxelles (Parlement UE) - 1,2-XYLENE O-XYLENE...
# 1                      Bonheiden - Ammonia - feature
# 2                   Oud-Turnhout - Ammonia - feature
# 3                Corroy-Le-Grand - Ammonia - feature
# 4                        Dourbes - Ammonia - feature
#       id                                              label    uom  \
# 0   6522  1,2-XYLENE O-XYLENE 6522 - btx, o-xyleen - pro...  µg/m³
# 1  10892  Ammonia 10892 - MINI DOAS - procedure, 42BO01 ...  µg/m³
# 2  10893  Ammonia 10893 - MINI DOAS - procedure, 42OT02 ...  µg/m³
# 3  10932  Ammonia 10932 - Unknown device - procedure, 43...  µg/m³
# 4  10933  Ammonia 10933 - Unknown device - procedure, 43...  µg/m³
#
#    station_id                                      station_label  longitude  \
# 0        6522  41B006 - Bruxelles (Parlement UE) - 1,2-XYLENE...   4.374388
# 1       10892             42BO01 - Bonheiden - Ammonia - feature   4.516484
# 2       10893          42OT02 - Oud-Turnhout - Ammonia - feature   5.011793
# 3       10932       43N063 - Corroy-Le-Grand - Ammonia - feature   4.668288
# 4       10933               43N100 - Dourbes - Ammonia - feature   4.594763
#
#     latitude altitude geometry_type station_type                 parameter  \
# 0  50.838631      NaN         Point      Feature  1,2-XYLENE O-XYLENE 6522
# 1  51.027061      NaN         Point      Feature             Ammonia 10892
# 2  51.346548      NaN         Point      Feature             Ammonia 10893
# 3  50.655439      NaN         Point      Feature             Ammonia 10932
# 4  50.095683      NaN         Point      Feature             Ammonia 10933
#
#           id_part        device_type  \
# 0   btx, o-xyleen  procedure, 41B006
# 1       MINI DOAS  procedure, 42BO01
# 2       MINI DOAS  procedure, 42OT02
# 3  Unknown device  procedure, 43N063
# 4  Unknown device  procedure, 43N100
#
#                                         station_info       parameter_name  \
# 0  Bruxelles (Parlement UE) - 1,2-XYLENE O-XYLENE...  1,2-XYLENE O-XYLENE
# 1                      Bonheiden - Ammonia - feature              Ammonia
# 2                   Oud-Turnhout - Ammonia - feature              Ammonia
# 3                Corroy-Le-Grand - Ammonia - feature              Ammonia
# 4                        Dourbes - Ammonia - feature              Ammonia
#
#   parameter_id
# 0         6522
# 1        10892
# 2        10893
# 3        10932
# 4        10933
# -1

# %%
#CATEGORY

df_category = pd.DataFrame(category)

print(df_category)

df_category.to_sql(
    name='Category',        # target table name
    con=engine,             # SQLAlchemy engine
    if_exists='replace',    # 'replace', 'append', or 'fail'
    index=False,            # do not write DataFrame index as a column
)
# Out:
#        id                                    label
# 0     482                      1,2-XYLENE O-XYLENE
# 1      35                                  Ammonia
# 2   64102                    Atmospheric  Pressure
# 3      20                                  Benzene
# 4     391                             Black Carbon
# 5      71                           Carbon Dioxide
# 6      10                          Carbon Monoxide
# 7    4013                Elemental gaseous mercury
# 8     431                             Ethylbenzene
# 9     464                               M+P-xylene
# 10      8                         Nitrogen dioxide
# 11     38                        Nitrogen monoxide
# 12      7                                    Ozone
# 13  90517  Particle number concentration 10-800 nm
# 14   6002                Particulate Matter < 1 µm
# 15      5               Particulate Matter < 10 µm
# 16   6001              Particulate Matter < 2.5 µm
# 17  62106                        Relative Humidity
# 18      1                          Sulphur dioxide
# 19  62101                              Temperature
# 20     21                                  Toluene
# 21  61102                           Wind Direction
# 22  61110                      Wind Speed (scalar)
# -1
